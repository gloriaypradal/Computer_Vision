# %% [markdown]
# <a href="https://colab.research.google.com/github/gloriaypradal/Computer_Vision/blob/main/DSC680_Project1_Apple_week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
from bs4 import BeautifulSoup
import requests
import os
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
url = "https://www.usinflationcalculator.com/inflation/consumer-price-index-and-annual-percent-changes-from-1913-to-2008/"
url_req = requests.get(url).text

soup = BeautifulSoup(url_req, 'html')
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
tables = soup.find_all( "table")
data = tables[0].tbody.find_all('tr')
df_data = [[td.getText().strip() for td in tr.find_all('td')] for tr in data]
df_data
# Out:
# [['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Annual',
#   'Percent Change'],
#  ['Year',
#   'Jan',
#   'Feb',
#   'Mar',
#   'Apr',
#   'May',
#   'June',
#   'July',
#   'Aug',
#   'Sep',
#   'Oct',
#   'Nov',
#   'Dec',
#   'Avg',
#   'Dec-Dec',
#   'Avg-Avg'],
#  ['1913',
#   '9.8',
#   '9.8',
#   '9.8',
#   '9.8',
#   '9.7',
#   '9.8',
#   '9.9',
#   '9.9',
#   '10.0',
#   '10.0',
#   '10.1',
#   '10.0',
#   '9.9',
#   '–',
#   '–'],
#  ['1914',
#   '10.0',
#   '9.9',
#   '9.9',
#   '9.8',
#   '9.9',
#   '9.9',
#   '10.0',
#   '10.2',
#   '10.2',
#   '10.1',
#   '10.2',
#   '10.1',
#   '10.0',
#   '1.0',
#   '1.0'],
#  ['1915',
#   '10.1',
#   '10.0',
#   '9.9',
#   '10.0',
#   '10.1',
#   '10.1',
#   '10.1',
#   '10.1',
#   '10.1',
#   '10.2',
#   '10.3',
#   '10.3',
#   '10.1',
#   '2.0',
#   '1.0'],
#  ['1916',
#   '10.4',
#   '10.4',
#   '10.5',
#   '10.6',
#   '10.7',
#   '10.8',
#   '10.8',
#   '10.9',
#   '11.1',
#   '11.3',
#   '11.5',
#   '11.6',
#   '10.9',
#   '12.6',
#   '7.9'],
#  ['1917',
#   '11.7',
#   '12.0',
#   '12.0',
#   '12.6',
#   '12.8',
#   '13.0',
#   '12.8',
#   '13.0',
#   '13.3',
#   '13.5',
#   '13.5',
#   '13.7',
#   '12.8',
#   '18.1',
#   '17.4'],
#  ['1918',
#   '14.0',
#   '14.1',
#   '14.0',
#   '14.2',
#   '14.5',
#   '14.7',
#   '15.1',
#   '15.4',
#   '15.7',
#   '16.0',
#   '16.3',
#   '16.5',
#   '15.1',
#   '20.4',
#   '18.0'],
#  ['1919',
#   '16.5',
#   '16.2',
#   '16.4',
#   '16.7',
#   '16.9',
#   '16.9',
#   '17.4',
#   '17.7',
#   '17.8',
#   '18.1',
#   '18.5',
#   '18.9',
#   '17.3',
#   '14.5',
#   '14.6'],
#  ['1920',
#   '19.3',
#   '19.5',
#   '19.7',
#   '20.3',
#   '20.6',
#   '20.9',
#   '20.8',
#   '20.3',
#   '20.0',
#   '19.9',
#   '19.8',
#   '19.4',
#   '20.0',
#   '2.6',
#   '15.6'],
#  ['1921',
#   '19.0',
#   '18.4',
#   '18.3',
#   '18.1',
#   '17.7',
#   '17.6',
#   '17.7',
#   '17.7',
#   '17.5',
#   '17.5',
#   '17.4',
#   '17.3',
#   '17.9',
#   '-10.8',
#   '-10.5'],
#  ['1922',
#   '16.9',
#   '16.9',
#   '16.7',
#   '16.7',
#   '16.7',
#   '16.7',
#   '16.8',
#   '16.6',
#   '16.6',
#   '16.7',
#   '16.8',
#   '16.9',
#   '16.8',
#   '-2.3',
#   '-6.1'],
#  ['1923',
#   '16.8',
#   '16.8',
#   '16.8',
#   '16.9',
#   '16.9',
#   '17.0',
#   '17.2',
#   '17.1',
#   '17.2',
#   '17.3',
#   '17.3',
#   '17.3',
#   '17.1',
#   '2.4',
#   '1.8'],
#  ['1924',
#   '17.3',
#   '17.2',
#   '17.1',
#   '17.0',
#   '17.0',
#   '17.0',
#   '17.1',
#   '17.0',
#   '17.1',
#   '17.2',
#   '17.2',
#   '17.3',
#   '17.1',
#   '0.0',
#   '0.0'],
#  ['1925',
#   '17.3',
#   '17.2',
#   '17.3',
#   '17.2',
#   '17.3',
#   '17.5',
#   '17.7',
#   '17.7',
#   '17.7',
#   '17.7',
#   '18.0',
#   '17.9',
#   '17.5',
#   '3.5',
#   '2.3'],
#  ['1926',
#   '17.9',
#   '17.9',
#   '17.8',
#   '17.9',
#   '17.8',
#   '17.7',
#   '17.5',
#   '17.4',
#   '17.5',
#   '17.6',
#   '17.7',
#   '17.7',
#   '17.7',
#   '-1.1',
#   '1.1'],
#  ['1927',
#   '17.5',
#   '17.4',
#   '17.3',
#   '17.3',
#   '17.4',
#   '17.6',
#   '17.3',
#   '17.2',
#   '17.3',
#   '17.4',
#   '17.3',
#   '17.3',
#   '17.4',
#   '-2.3',
#   '-1.7'],
#  ['1928',
#   '17.3',
#   '17.1',
#   '17.1',
#   '17.1',
#   '17.2',
#   '17.1',
#   '17.1',
#   '17.1',
#   '17.3',
#   '17.2',
#   '17.2',
#   '17.1',
#   '17.1',
#   '-1.2',
#   '-1.7'],
#  ['1929',
#   '17.1',
#   '17.1',
#   '17.0',
#   '16.9',
#   '17.0',
#   '17.1',
#   '17.3',
#   '17.3',
#   '17.3',
#   '17.3',
#   '17.3',
#   '17.2',
#   '17.1',
#   '0.6',
#   '0.0'],
#  ['1930',
#   '17.1',
#   '17.0',
#   '16.9',
#   '17.0',
#   '16.9',
#   '16.8',
#   '16.6',
#   '16.5',
#   '16.6',
#   '16.5',
#   '16.4',
#   '16.1',
#   '16.7',
#   '-6.4',
#   '-2.3'],
#  ['1931',
#   '15.9',
#   '15.7',
#   '15.6',
#   '15.5',
#   '15.3',
#   '15.1',
#   '15.1',
#   '15.1',
#   '15.0',
#   '14.9',
#   '14.7',
#   '14.6',
#   '15.2',
#   '-9.3',
#   '-9.0'],
#  ['1932',
#   '14.3',
#   '14.1',
#   '14.0',
#   '13.9',
#   '13.7',
#   '13.6',
#   '13.6',
#   '13.5',
#   '13.4',
#   '13.3',
#   '13.2',
#   '13.1',
#   '13.7',
#   '-10.3',
#   '-9.9'],
#  ['1933',
#   '12.9',
#   '12.7',
#   '12.6',
#   '12.6',
#   '12.6',
#   '12.7',
#   '13.1',
#   '13.2',
#   '13.2',
#   '13.2',
#   '13.2',
#   '13.2',
#   '13.0',
#   '0.8',
#   '-5.1'],
#  ['1934',
#   '13.2',
#   '13.3',
#   '13.3',
#   '13.3',
#   '13.3',
#   '13.4',
#   '13.4',
#   '13.4',
#   '13.6',
#   '13.5',
#   '13.5',
#   '13.4',
#   '13.4',
#   '1.5',
#   '3.1'],
#  ['1935',
#   '13.6',
#   '13.7',
#   '13.7',
#   '13.8',
#   '13.8',
#   '13.7',
#   '13.7',
#   '13.7',
#   '13.7',
#   '13.7',
#   '13.8',
#   '13.8',
#   '13.7',
#   '3.0',
#   '2.2'],
#  ['1936',
#   '13.8',
#   '13.8',
#   '13.7',
#   '13.7',
#   '13.7',
#   '13.8',
#   '13.9',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.0',
#   '13.9',
#   '1.4',
#   '1.5'],
#  ['1937',
#   '14.1',
#   '14.1',
#   '14.2',
#   '14.3',
#   '14.4',
#   '14.4',
#   '14.5',
#   '14.5',
#   '14.6',
#   '14.6',
#   '14.5',
#   '14.4',
#   '14.4',
#   '2.9',
#   '3.6'],
#  ['1938',
#   '14.2',
#   '14.1',
#   '14.1',
#   '14.2',
#   '14.1',
#   '14.1',
#   '14.1',
#   '14.1',
#   '14.1',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.1',
#   '-2.8',
#   '-2.1'],
#  ['1939',
#   '14.0',
#   '13.9',
#   '13.9',
#   '13.8',
#   '13.8',
#   '13.8',
#   '13.8',
#   '13.8',
#   '14.1',
#   '14.0',
#   '14.0',
#   '14.0',
#   '13.9',
#   '0.0',
#   '-1.4'],
#  ['1940',
#   '13.9',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.1',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.0',
#   '14.1',
#   '14.0',
#   '0.7',
#   '0.7'],
#  ['1941',
#   '14.1',
#   '14.1',
#   '14.2',
#   '14.3',
#   '14.4',
#   '14.7',
#   '14.7',
#   '14.9',
#   '15.1',
#   '15.3',
#   '15.4',
#   '15.5',
#   '14.7',
#   '9.9',
#   '5.0'],
#  ['1942',
#   '15.7',
#   '15.8',
#   '16.0',
#   '16.1',
#   '16.3',
#   '16.3',
#   '16.4',
#   '16.5',
#   '16.5',
#   '16.7',
#   '16.8',
#   '16.9',
#   '16.3',
#   '9.0',
#   '10.9'],
#  ['1943',
#   '16.9',
#   '16.9',
#   '17.2',
#   '17.4',
#   '17.5',
#   '17.5',
#   '17.4',
#   '17.3',
#   '17.4',
#   '17.4',
#   '17.4',
#   '17.4',
#   '17.3',
#   '3.0',
#   '6.1'],
#  ['1944',
#   '17.4',
#   '17.4',
#   '17.4',
#   '17.5',
#   '17.5',
#   '17.6',
#   '17.7',
#   '17.7',
#   '17.7',
#   '17.7',
#   '17.7',
#   '17.8',
#   '17.6',
#   '2.3',
#   '1.7'],
#  ['1945',
#   '17.8',
#   '17.8',
#   '17.8',
#   '17.8',
#   '17.9',
#   '18.1',
#   '18.1',
#   '18.1',
#   '18.1',
#   '18.1',
#   '18.1',
#   '18.2',
#   '18.0',
#   '2.2',
#   '2.3'],
#  ['1946',
#   '18.2',
#   '18.1',
#   '18.3',
#   '18.4',
#   '18.5',
#   '18.7',
#   '19.8',
#   '20.2',
#   '20.4',
#   '20.8',
#   '21.3',
#   '21.5',
#   '19.5',
#   '18.1',
#   '8.3'],
#  ['1947',
#   '21.5',
#   '21.5',
#   '21.9',
#   '21.9',
#   '21.9',
#   '22.0',
#   '22.2',
#   '22.5',
#   '23.0',
#   '23.0',
#   '23.1',
#   '23.4',
#   '22.3',
#   '8.8',
#   '14.4'],
#  ['1948',
#   '23.7',
#   '23.5',
#   '23.4',
#   '23.8',
#   '23.9',
#   '24.1',
#   '24.4',
#   '24.5',
#   '24.5',
#   '24.4',
#   '24.2',
#   '24.1',
#   '24.1',
#   '3.0',
#   '8.1'],
#  ['1949',
#   '24.0',
#   '23.8',
#   '23.8',
#   '23.9',
#   '23.8',
#   '23.9',
#   '23.7',
#   '23.8',
#   '23.9',
#   '23.7',
#   '23.8',
#   '23.6',
#   '23.8',
#   '-2.1',
#   '-1.2'],
#  ['1950',
#   '23.5',
#   '23.5',
#   '23.6',
#   '23.6',
#   '23.7',
#   '23.8',
#   '24.1',
#   '24.3',
#   '24.4',
#   '24.6',
#   '24.7',
#   '25.0',
#   '24.1',
#   '5.9',
#   '1.3'],
#  ['1951',
#   '25.4',
#   '25.7',
#   '25.8',
#   '25.8',
#   '25.9',
#   '25.9',
#   '25.9',
#   '25.9',
#   '26.1',
#   '26.2',
#   '26.4',
#   '26.5',
#   '26.0',
#   '6.0',
#   '7.9'],
#  ['1952',
#   '26.5',
#   '26.3',
#   '26.3',
#   '26.4',
#   '26.4',
#   '26.5',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.5',
#   '0.8',
#   '1.9'],
#  ['1953',
#   '26.6',
#   '26.5',
#   '26.6',
#   '26.6',
#   '26.7',
#   '26.8',
#   '26.8',
#   '26.9',
#   '26.9',
#   '27.0',
#   '26.9',
#   '26.9',
#   '26.7',
#   '0.7',
#   '0.8'],
#  ['1954',
#   '26.9',
#   '26.9',
#   '26.9',
#   '26.8',
#   '26.9',
#   '26.9',
#   '26.9',
#   '26.9',
#   '26.8',
#   '26.8',
#   '26.8',
#   '26.7',
#   '26.9',
#   '-0.7',
#   '0.7'],
#  ['1955',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.7',
#   '26.8',
#   '26.8',
#   '26.9',
#   '26.9',
#   '26.9',
#   '26.8',
#   '26.8',
#   '0.4',
#   '-0.4'],
#  ['1956',
#   '26.8',
#   '26.8',
#   '26.8',
#   '26.9',
#   '27.0',
#   '27.2',
#   '27.4',
#   '27.3',
#   '27.4',
#   '27.5',
#   '27.5',
#   '27.6',
#   '27.2',
#   '3.0',
#   '1.5'],
#  ['1957',
#   '27.6',
#   '27.7',
#   '27.8',
#   '27.9',
#   '28.0',
#   '28.1',
#   '28.3',
#   '28.3',
#   '28.3',
#   '28.3',
#   '28.4',
#   '28.4',
#   '28.1',
#   '2.9',
#   '3.3'],
#  ['1958',
#   '28.6',
#   '28.6',
#   '28.8',
#   '28.9',
#   '28.9',
#   '28.9',
#   '29.0',
#   '28.9',
#   '28.9',
#   '28.9',
#   '29.0',
#   '28.9',
#   '28.9',
#   '1.8',
#   '2.8'],
#  ['1959',
#   '29.0',
#   '28.9',
#   '28.9',
#   '29.0',
#   '29.0',
#   '29.1',
#   '29.2',
#   '29.2',
#   '29.3',
#   '29.4',
#   '29.4',
#   '29.4',
#   '29.1',
#   '1.7',
#   '0.7'],
#  ['1960',
#   '29.3',
#   '29.4',
#   '29.4',
#   '29.5',
#   '29.5',
#   '29.6',
#   '29.6',
#   '29.6',
#   '29.6',
#   '29.8',
#   '29.8',
#   '29.8',
#   '29.6',
#   '1.4',
#   '1.7'],
#  ['1961',
#   '29.8',
#   '29.8',
#   '29.8',
#   '29.8',
#   '29.8',
#   '29.8',
#   '30.0',
#   '29.9',
#   '30.0',
#   '30.0',
#   '30.0',
#   '30.0',
#   '29.9',
#   '0.7',
#   '1.0'],
#  ['1962',
#   '30.0',
#   '30.1',
#   '30.1',
#   '30.2',
#   '30.2',
#   '30.2',
#   '30.3',
#   '30.3',
#   '30.4',
#   '30.4',
#   '30.4',
#   '30.4',
#   '30.2',
#   '1.3',
#   '1.0'],
#  ['1963',
#   '30.4',
#   '30.4',
#   '30.5',
#   '30.5',
#   '30.5',
#   '30.6',
#   '30.7',
#   '30.7',
#   '30.7',
#   '30.8',
#   '30.8',
#   '30.9',
#   '30.6',
#   '1.6',
#   '1.3'],
#  ['1964',
#   '30.9',
#   '30.9',
#   '30.9',
#   '30.9',
#   '30.9',
#   '31.0',
#   '31.1',
#   '31.0',
#   '31.1',
#   '31.1',
#   '31.2',
#   '31.2',
#   '31.0',
#   '1.0',
#   '1.3'],
#  ['1965',
#   '31.2',
#   '31.2',
#   '31.3',
#   '31.4',
#   '31.4',
#   '31.6',
#   '31.6',
#   '31.6',
#   '31.6',
#   '31.7',
#   '31.7',
#   '31.8',
#   '31.5',
#   '1.9',
#   '1.6'],
#  ['1966',
#   '31.8',
#   '32.0',
#   '32.1',
#   '32.3',
#   '32.3',
#   '32.4',
#   '32.5',
#   '32.7',
#   '32.7',
#   '32.9',
#   '32.9',
#   '32.9',
#   '32.4',
#   '3.5',
#   '2.9'],
#  ['1967',
#   '32.9',
#   '32.9',
#   '33.0',
#   '33.1',
#   '33.2',
#   '33.3',
#   '33.4',
#   '33.5',
#   '33.6',
#   '33.7',
#   '33.8',
#   '33.9',
#   '33.4',
#   '3.0',
#   '3.1'],
#  ['1968',
#   '34.1',
#   '34.2',
#   '34.3',
#   '34.4',
#   '34.5',
#   '34.7',
#   '34.9',
#   '35.0',
#   '35.1',
#   '35.3',
#   '35.4',
#   '35.5',
#   '34.8',
#   '4.7',
#   '4.2'],
#  ['1969',
#   '35.6',
#   '35.8',
#   '36.1',
#   '36.3',
#   '36.4',
#   '36.6',
#   '36.8',
#   '37.0',
#   '37.1',
#   '37.3',
#   '37.5',
#   '37.7',
#   '36.7',
#   '6.2',
#   '5.5'],
#  ['1970',
#   '37.8',
#   '38.0',
#   '38.2',
#   '38.5',
#   '38.6',
#   '38.8',
#   '39.0',
#   '39.0',
#   '39.2',
#   '39.4',
#   '39.6',
#   '39.8',
#   '38.8',
#   '5.6',
#   '5.7'],
#  ['1971',
#   '39.8',
#   '39.9',
#   '40.0',
#   '40.1',
#   '40.3',
#   '40.6',
#   '40.7',
#   '40.8',
#   '40.8',
#   '40.9',
#   '40.9',
#   '41.1',
#   '40.5',
#   '3.3',
#   '4.4'],
#  ['1972',
#   '41.1',
#   '41.3',
#   '41.4',
#   '41.5',
#   '41.6',
#   '41.7',
#   '41.9',
#   '42.0',
#   '42.1',
#   '42.3',
#   '42.4',
#   '42.5',
#   '41.8',
#   '3.4',
#   '3.2'],
#  ['1973',
#   '42.6',
#   '42.9',
#   '43.3',
#   '43.6',
#   '43.9',
#   '44.2',
#   '44.3',
#   '45.1',
#   '45.2',
#   '45.6',
#   '45.9',
#   '46.2',
#   '44.4',
#   '8.7',
#   '6.2'],
#  ['1974',
#   '46.6',
#   '47.2',
#   '47.8',
#   '48.0',
#   '48.6',
#   '49.0',
#   '49.4',
#   '50.0',
#   '50.6',
#   '51.1',
#   '51.5',
#   '51.9',
#   '49.3',
#   '12.3',
#   '11.0'],
#  ['1975',
#   '52.1',
#   '52.5',
#   '52.7',
#   '52.9',
#   '53.2',
#   '53.6',
#   '54.2',
#   '54.3',
#   '54.6',
#   '54.9',
#   '55.3',
#   '55.5',
#   '53.8',
#   '6.9',
#   '9.1'],
#  ['1976',
#   '55.6',
#   '55.8',
#   '55.9',
#   '56.1',
#   '56.5',
#   '56.8',
#   '57.1',
#   '57.4',
#   '57.6',
#   '57.9',
#   '58.0',
#   '58.2',
#   '56.9',
#   '4.9',
#   '5.8'],
#  ['1977',
#   '58.5',
#   '59.1',
#   '59.5',
#   '60.0',
#   '60.3',
#   '60.7',
#   '61.0',
#   '61.2',
#   '61.4',
#   '61.6',
#   '61.9',
#   '62.1',
#   '60.6',
#   '6.7',
#   '6.5'],
#  ['1978',
#   '62.5',
#   '62.9',
#   '63.4',
#   '63.9',
#   '64.5',
#   '65.2',
#   '65.7',
#   '66.0',
#   '66.5',
#   '67.1',
#   '67.4',
#   '67.7',
#   '65.2',
#   '9.0',
#   '7.6'],
#  ['1979',
#   '68.3',
#   '69.1',
#   '69.8',
#   '70.6',
#   '71.5',
#   '72.3',
#   '73.1',
#   '73.8',
#   '74.6',
#   '75.2',
#   '75.9',
#   '76.7',
#   '72.6',
#   '13.3',
#   '11.3'],
#  ['1980',
#   '77.8',
#   '78.9',
#   '80.1',
#   '81.0',
#   '81.8',
#   '82.7',
#   '82.7',
#   '83.3',
#   '84.0',
#   '84.8',
#   '85.5',
#   '86.3',
#   '82.4',
#   '12.5',
#   '13.5'],
#  ['1981',
#   '87.0',
#   '87.9',
#   '88.5',
#   '89.1',
#   '89.8',
#   '90.6',
#   '91.6',
#   '92.3',
#   '93.2',
#   '93.4',
#   '93.7',
#   '94.0',
#   '90.9',
#   '8.9',
#   '10.3'],
#  ['1982',
#   '94.3',
#   '94.6',
#   '94.5',
#   '94.9',
#   '95.8',
#   '97.0',
#   '97.5',
#   '97.7',
#   '97.9',
#   '98.2',
#   '98.0',
#   '97.6',
#   '96.5',
#   '3.8',
#   '6.2'],
#  ['1983',
#   '97.8',
#   '97.9',
#   '97.9',
#   '98.6',
#   '99.2',
#   '99.5',
#   '99.9',
#   '100.2',
#   '100.7',
#   '101.0',
#   '101.2',
#   '101.3',
#   '99.6',
#   '3.8',
#   '3.2'],
#  ['1984',
#   '101.9',
#   '102.4',
#   '102.6',
#   '103.1',
#   '103.4',
#   '103.7',
#   '104.1',
#   '104.5',
#   '105.0',
#   '105.3',
#   '105.3',
#   '105.3',
#   '103.9',
#   '3.9',
#   '4.3'],
#  ['1985',
#   '105.5',
#   '106.0',
#   '106.4',
#   '106.9',
#   '107.3',
#   '107.6',
#   '107.8',
#   '108.0',
#   '108.3',
#   '108.7',
#   '109.0',
#   '109.3',
#   '107.6',
#   '3.8',
#   '3.6'],
#  ['1986',
#   '109.6',
#   '109.3',
#   '108.8',
#   '108.6',
#   '108.9',
#   '109.5',
#   '109.5',
#   '109.7',
#   '110.2',
#   '110.3',
#   '110.4',
#   '110.5',
#   '109.6',
#   '1.1',
#   '1.9'],
#  ['1987',
#   '111.2',
#   '111.6',
#   '112.1',
#   '112.7',
#   '113.1',
#   '113.5',
#   '113.8',
#   '114.4',
#   '115.0',
#   '115.3',
#   '115.4',
#   '115.4',
#   '113.6',
#   '4.4',
#   '3.6'],
#  ['1988',
#   '115.7',
#   '116.0',
#   '116.5',
#   '117.1',
#   '117.5',
#   '118.0',
#   '118.5',
#   '119.0',
#   '119.8',
#   '120.2',
#   '120.3',
#   '120.5',
#   '118.3',
#   '4.4',
#   '4.1'],
#  ['1989',
#   '121.1',
#   '121.6',
#   '122.3',
#   '123.1',
#   '123.8',
#   '124.1',
#   '124.4',
#   '124.6',
#   '125.0',
#   '125.6',
#   '125.9',
#   '126.1',
#   '124.0',
#   '4.6',
#   '4.8'],
#  ['1990',
#   '127.4',
#   '128.0',
#   '128.7',
#   '128.9',
#   '129.2',
#   '129.9',
#   '130.4',
#   '131.6',
#   '132.7',
#   '133.5',
#   '133.8',
#   '133.8',
#   '130.7',
#   '6.1',
#   '5.4'],
#  ['1991',
#   '134.6',
#   '134.8',
#   '135.0',
#   '135.2',
#   '135.6',
#   '136.0',
#   '136.2',
#   '136.6',
#   '137.2',
#   '137.4',
#   '137.8',
#   '137.9',
#   '136.2',
#   '3.1',
#   '4.2'],
#  ['1992',
#   '138.1',
#   '138.6',
#   '139.3',
#   '139.5',
#   '139.7',
#   '140.2',
#   '140.5',
#   '140.9',
#   '141.3',
#   '141.8',
#   '142.0',
#   '141.9',
#   '140.3',
#   '2.9',
#   '3.0'],
#  ['1993',
#   '142.6',
#   '143.1',
#   '143.6',
#   '144.0',
#   '144.2',
#   '144.4',
#   '144.4',
#   '144.8',
#   '145.1',
#   '145.7',
#   '145.8',
#   '145.8',
#   '144.5',
#   '2.7',
#   '3.0'],
#  ['1994',
#   '146.2',
#   '146.7',
#   '147.2',
#   '147.4',
#   '147.5',
#   '148.0',
#   '148.4',
#   '149.0',
#   '149.4',
#   '149.5',
#   '149.7',
#   '149.7',
#   '148.2',
#   '2.7',
#   '2.6'],
#  ['1995',
#   '150.3',
#   '150.9',
#   '151.4',
#   '151.9',
#   '152.2',
#   '152.5',
#   '152.5',
#   '152.9',
#   '153.2',
#   '153.7',
#   '153.6',
#   '153.5',
#   '152.4',
#   '2.5',
#   '2.8'],
#  ['1996',
#   '154.4',
#   '154.9',
#   '155.7',
#   '156.3',
#   '156.6',
#   '156.7',
#   '157.0',
#   '157.3',
#   '157.8',
#   '158.3',
#   '158.6',
#   '158.6',
#   '156.9',
#   '3.3',
#   '3.0'],
#  ['1997',
#   '159.1',
#   '159.6',
#   '160.0',
#   '160.2',
#   '160.1',
#   '160.3',
#   '160.5',
#   '160.8',
#   '161.2',
#   '161.6',
#   '161.5',
#   '161.3',
#   '160.5',
#   '1.7',
#   '2.3'],
#  ['1998',
#   '161.6',
#   '161.9',
#   '162.2',
#   '162.5',
#   '162.8',
#   '163.0',
#   '163.2',
#   '163.4',
#   '163.6',
#   '164.0',
#   '164.0',
#   '163.9',
#   '163.0',
#   '1.6',
#   '1.6'],
#  ['1999',
#   '164.3',
#   '164.5',
#   '165.0',
#   '166.2',
#   '166.2',
#   '166.2',
#   '166.7',
#   '167.1',
#   '167.9',
#   '168.2',
#   '168.3',
#   '168.3',
#   '166.6',
#   '2.7',
#   '2.2'],
#  ['2000',
#   '168.8',
#   '169.8',
#   '171.2',
#   '171.3',
#   '171.5',
#   '172.4',
#   '172.8',
#   '172.8',
#   '173.7',
#   '174.0',
#   '174.1',
#   '174.0',
#   '172.2',
#   '3.4',
#   '3.4'],
#  ['2001',
#   '175.1',
#   '175.8',
#   '176.2',
#   '176.9',
#   '177.7',
#   '178.0',
#   '177.5',
#   '177.5',
#   '178.3',
#   '177.7',
#   '177.4',
#   '176.7',
#   '177.1',
#   '1.6',
#   '2.8'],
#  ['2002',
#   '177.1',
#   '177.8',
#   '178.8',
#   '179.8',
#   '179.8',
#   '179.9',
#   '180.1',
#   '180.7',
#   '181.0',
#   '181.3',
#   '181.3',
#   '180.9',
#   '179.9',
#   '2.4',
#   '1.6'],
#  ['2003',
#   '181.7',
#   '183.1',
#   '184.2',
#   '183.8',
#   '183.5',
#   '183.7',
#   '183.9',
#   '184.6',
#   '185.2',
#   '185.0',
#   '184.5',
#   '184.3',
#   '184.0',
#   '1.9',
#   '2.3'],
#  ['2004',
#   '185.2',
#   '186.2',
#   '187.4',
#   '188.0',
#   '189.1',
#   '189.7',
#   '189.4',
#   '189.5',
#   '189.9',
#   '190.9',
#   '191.0',
#   '190.3',
#   '188.9',
#   '3.3',
#   '2.7'],
#  ['2005',
#   '190.7',
#   '191.8',
#   '193.3',
#   '194.6',
#   '194.4',
#   '194.5',
#   '195.4',
#   '196.4',
#   '198.8',
#   '199.2',
#   '197.6',
#   '196.8',
#   '195.3',
#   '3.4',
#   '3.4'],
#  ['2006',
#   '198.3',
#   '198.7',
#   '199.8',
#   '201.5',
#   '202.5',
#   '202.9',
#   '203.5',
#   '203.9',
#   '202.9',
#   '201.8',
#   '201.5',
#   '201.8',
#   '201.6',
#   '2.5',
#   '3.2'],
#  ['2007',
#   '202.4',
#   '203.5',
#   '205.4',
#   '206.7',
#   '207.9',
#   '208.4',
#   '208.3',
#   '207.9',
#   '208.5',
#   '208.9',
#   '210.2',
#   '210.0',
#   '207.3',
#   '4.1',
#   '2.8'],
#  ['2008',
#   '211.1',
#   '211.7',
#   '213.5',
#   '214.8',
#   '216.6',
#   '218.8',
#   '219.964',
#   '219.086',
#   '218.783',
#   '216.573',
#   '212.425',
#   '210.228',
#   '215.303',
#   '0.1',
#   '3.8'],
#  ['2009',
#   '211.143',
#   '212.193',
#   '212.709',
#   '213.240',
#   '213.856',
#   '215.693',
#   '215.351',
#   '215.834',
#   '215.969',
#   '216.177',
#   '216.330',
#   '215.949',
#   '214.537',
#   '2.7',
#   '-0.4'],
#  ['2010',
#   '216.687',
#   '216.741',
#   '217.631',
#   '218.009',
#   '218.178',
#   '217.965',
#   '218.011',
#   '218.312',
#   '218.439',
#   '218.711',
#   '218.803',
#   '219.179',
#   '218.056',
#   '1.5',
#   '1.6'],
#  ['2011',
#   '220.223',
#   '221.309',
#   '223.467',
#   '224.906',
#   '225.964',
#   '225.722',
#   '225.922',
#   '226.545',
#   '226.889',
#   '226.421',
#   '226.230',
#   '225.672',
#   '224.939',
#   '3.0',
#   '3.2'],
#  ['2012',
#   '226.655',
#   '227.663',
#   '229.392',
#   '230.085',
#   '229.815',
#   '229.478',
#   '229.104',
#   '230.379',
#   '231.407',
#   '231.317',
#   '230.221',
#   '229.601',
#   '229.594',
#   '1.7',
#   '2.1'],
#  ['2013',
#   '230.280',
#   '232.166',
#   '232.773',
#   '232.531',
#   '232.945',
#   '233.504',
#   '233.596',
#   '233.877',
#   '234.149',
#   '233.546',
#   '233.069',
#   '233.049',
#   '232.957',
#   '1.5',
#   '1.5'],
#  ['2014',
#   '233.916',
#   '234.781',
#   '236.293',
#   '237.072',
#   '237.900',
#   '238.343',
#   '238.250',
#   '237.852',
#   '238.031',
#   '237.433',
#   '236.151',
#   '234.812',
#   '236.736',
#   '0.8',
#   '1.6'],
#  ['2015',
#   '233.707',
#   '234.722',
#   '236.119',
#   '236.599',
#   '237.805',
#   '238.638',
#   '238.654',
#   '238.316',
#   '237.945',
#   '237.838',
#   '237.336',
#   '236.525',
#   '237.017',
#   '0.7',
#   '0.1'],
#  ['2016',
#   '236.916',
#   '237.111',
#   '238.132',
#   '239.261',
#   '240.236',
#   '241.038',
#   '240.647',
#   '240.853',
#   '241.428',
#   '241.729',
#   '241.353',
#   '241.432',
#   '240.007',
#   '2.1',
#   '1.3'],
#  ['2017',
#   '242.839',
#   '243.603',
#   '243.801',
#   '244.524',
#   '244.733',
#   '244.955',
#   '244.786',
#   '245.519',
#   '246.819',
#   '246.663',
#   '246.669',
#   '246.524',
#   '245.120',
#   '2.1',
#   '2.1'],
#  ['2018',
#   '247.867',
#   '248.991',
#   '249.554',
#   '250.546',
#   '251.588',
#   '251.989',
#   '252.006',
#   '252.146',
#   '252.439',
#   '252.885',
#   '252.038',
#   '251.233',
#   '251.107',
#   '1.9',
#   '2.4'],
#  ['2019',
#   '251.712',
#   '252.776',
#   '254.202',
#   '255.548',
#   '256.092',
#   '256.143',
#   '256.571',
#   '256.558',
#   '256.759',
#   '257.346',
#   '257.208',
#   '256.974',
#   '255.657',
#   '2.3',
#   '1.8'],
#  ['2020',
#   '257.971',
#   '258.678',
#   '258.115',
#   '256.389',
#   '256.394',
#   '257.797',
#   '259.101',
#   '259.918',
#   '260.280',
#   '260.388',
#   '260.229',
#   '260.474',
#   '258.811',
#   '1.4',
#   '1.2'],
#  ['2021',
#   '261.582',
#   '263.014',
#   '264.877',
#   '267.054',
#   '269.195',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']]

# %%
df1 = pd.DataFrame(df_data, columns = df_data[1:2])
df1 = df1.drop([0,1])
df1.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May  ...   Oct   Nov   Dec   Avg Dec-Dec Avg-Avg
# 2  1913   9.8   9.8   9.8   9.8   9.7  ...  10.0  10.1  10.0   9.9       –       –
# 3  1914  10.0   9.9   9.9   9.8   9.9  ...  10.1  10.2  10.1  10.0     1.0     1.0
# 4  1915  10.1  10.0   9.9  10.0  10.1  ...  10.2  10.3  10.3  10.1     2.0     1.0
# 5  1916  10.4  10.4  10.5  10.6  10.7  ...  11.3  11.5  11.6  10.9    12.6     7.9
# 6  1917  11.7  12.0  12.0  12.6  12.8  ...  13.5  13.5  13.7  12.8    18.1    17.4
#
# [5 rows x 16 columns]

# %%
df1.dtypes
# Out:
# Year         int64
# Jan        float64
# Feb        float64
# Mar        float64
# Apr        float64
# May        float64
# June       float64
# July       float64
# Aug        float64
# Sep        float64
# Oct        float64
# Nov        float64
# Dec        float64
# Avg        float64
# Dec-Dec     object
# Avg-Avg     object
# dtype: object

# %%
plt.figure(figsize=(20,6))
plt.grid(False)
plt.xlabel('Dates')
plt.ylabel('Values')
plt.plot(df1["Avg-Avg"], df1["Year"])
plt.title('Apple closing price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0d3292044d59> in <module>()
#       3 plt.xlabel('Dates')
#       4 plt.ylabel('Values')
# ----> 5 plt.plot(df1["Avg-Avg"], df1["Year"])
#       6 plt.title('Apple closing price')
#       7 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2876                 if self.columns.nlevels > 1:
#    2877                     return self._getitem_multilevel(key)
# -> 2878                 return self._get_item_cache(key)
#    2879
#    2880         # Do we have a slicer (on rows)?
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3541
#    3542             loc = self.columns.get_loc(item)
# -> 3543             values = self._mgr.iget(loc)
#    3544             res = self._box_col_values(values, loc)
#    3545
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in iget(self, i)
#     995         Return the data as a SingleBlockManager.
#     996         """
# --> 997         block = self.blocks[self.blknos[i]]
#     998         values = block.iget(self.blklocs[i])
#     999
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
df_apple = pd.read_csv("AAPL_processed1.csv")
df_apple['Date'] = pd.to_datetime(df_apple['Date'])
df_apple.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100751  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095495  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088485  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090676   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.093304   73449600

# %%
df_apple.describe()
# Out:
#                Open          High  ...     Adj Close        Volume
# count  10218.000000  10218.000000  ...  10218.000000  1.021800e+04
# mean      11.300340     11.421450  ...     10.725626  3.367509e+08
# std       23.212108     23.473441  ...     22.898992  3.408031e+08
# min        0.049665      0.049665  ...      0.038548  0.000000e+00
# 25%        0.276786      0.283281  ...      0.232184  1.286682e+08
# 50%        0.450893      0.459910  ...      0.375689  2.246118e+08
# 75%       12.342054     12.426607  ...     10.625787  4.189094e+08
# max      143.600006    145.089996  ...    142.704010  7.421641e+09
#
# [8 rows x 6 columns]

# %%
plt.figure(figsize=(20,6))
plt.grid(False)
plt.xlabel('Dates')
plt.ylabel('Close Prices')
plt.plot(df_apple["Date" ],df_apple['Close'])
plt.title('Apple closing price')
plt.xticks(fontsize= 8)
plt.show()

# %%
df_closing_apple = df_apple['Close']

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.figure(figsize=(20,6))
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
   
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
    
test_stationarity(df_closing_apple)
# Out:
# Results of dickey fuller test
# Test Statistics                    5.417971
# p-value                            1.000000
# No. of lags used                  39.000000
# Number of observations used    10178.000000
# critical value (1%)               -3.430993
# critical value (5%)               -2.861824
# critical value (10%)              -2.566921
# dtype: float64

# %%
# reading google
df_google = pd.read_csv("GOOG_processed1.csv")
df_google['Date'] = pd.to_datetime(df_google['Date'])
df_google.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
def plotting_1(data, title):
  plt.figure(figsize=(20,6))
  plt.grid(False)
  plt.xlabel('Dates')
  plt.ylabel('Close Prices')
  plt.plot(data["Date" ],data['Close'])
  plt.title(title)
  plt.show()

# %%
plotting_1(df_google, "Google Closing Price")

# %%
df_closing_google = df_google["Close"]

# %%
test_stationarity(df_closing_google)
# Out:
# Results of dickey fuller test
# Test Statistics                   4.423959
# p-value                           1.000000
# No. of lags used                 31.000000
# Number of observations used    4211.000000
# critical value (1%)              -3.431904
# critical value (5%)              -2.862227
# critical value (10%)             -2.567135
# dtype: float64

# %%
df_disney = pd.read_csv("DIS.csv")
df_disney.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1962-01-02  0.092908  0.096026  0.092908  0.092908   0.058398   841958
# 1  1962-01-03  0.092908  0.094467  0.092908  0.094155   0.059182   801865
# 2  1962-01-04  0.094155  0.094467  0.093532  0.094155   0.059182   962238
# 3  1962-01-05  0.094155  0.094779  0.093844  0.094467   0.059378   962238
# 4  1962-01-08  0.094467  0.095714  0.092285  0.094155   0.059182  1282984

# %%
df_disney['Date'] = pd.to_datetime(df_disney['Date'])

# %%
df_disney.to_csv("DIS_processed1.csv")

# %%
plotting_1(df_disney, "Disney Closing Price")

# %%
df_closing_disney = df_disney["Close"]

# %%
test_stationarity(df_closing_disney)
# Out:
# Results of dickey fuller test
# Test Statistics                    2.010584
# p-value                            0.998687
# No. of lags used                  42.000000
# Number of observations used    14931.000000
# critical value (1%)               -3.430788
# critical value (5%)               -2.861734
# critical value (10%)              -2.566873
# dtype: float64

# %%
df_microsoft = pd.read_csv("MSFT.csv")
df_microsoft.head()
print(df_microsoft.describe())
print(df_microsoft.isnull().sum())
df_microsoft['Date'] = pd.to_datetime(df_microsoft['Date'])
df_microsoft.to_csv("MSFT_processed1.csv")
# Out:
#               Open         High  ...    Adj Close        Volume
# count  8895.000000  8895.000000  ...  8895.000000  8.895000e+03
# mean     35.759181    36.143955  ...    30.766995  5.938352e+07
# std      46.194483    46.656073  ...    46.327213  3.856866e+07
# min       0.088542     0.092014  ...     0.057208  2.304000e+06
# 25%       3.871094     3.916016  ...     2.453063  3.540120e+07
# 50%      26.625000    26.910000  ...    18.731800  5.260230e+07
# 75%      37.245001    37.599998  ...    27.498417  7.327175e+07
# max     266.230011   267.850006  ...   266.690002  1.031789e+09
#
# [8 rows x 6 columns]
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plotting_1(df_microsoft, "Microsoft Closing Price")

# %%
df_closing_microsoft = df_microsoft["Close"]
test_stationarity(df_closing_disney)
# Out:
# Results of dickey fuller test
# Test Statistics                    2.010584
# p-value                            0.998687
# No. of lags used                  42.000000
# Number of observations used    14931.000000
# critical value (1%)               -3.430788
# critical value (5%)               -2.861734
# critical value (10%)              -2.566873
# dtype: float64

# %%
df_dell = pd.read_csv("DELL.csv")
df_dell.head()
print(df_dell.describe())
print(df_dell.isnull().sum())
df_dell['Date'] = pd.to_datetime(df_dell['Date'])
df_dell.to_csv("DELL_processed1.csv")
# Out:
#               Open         High  ...    Adj Close        Volume
# count  1223.000000  1223.000000  ...  1223.000000  1.223000e+03
# mean     51.356399    51.977937  ...    51.373585  3.024094e+06
# std      17.023809    17.164241  ...    17.029302  3.781666e+06
# min      23.643412    24.086378  ...    23.671097  1.132360e+05
# 25%      39.700996    40.517719  ...    39.742525  1.636024e+06
# 50%      49.500000    50.080002  ...    49.459999  2.295800e+06
# 75%      58.120155    58.687708  ...    57.898672  3.213046e+06
# max     104.209999   104.620003  ...   103.980003  7.496562e+07
#
# [8 rows x 6 columns]
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plotting_1(df_dell, "DELL Closing Price")

# %%
df_closing_dell = df_dell["Close"]
test_stationarity(df_closing_dell)
# Out:
# Results of dickey fuller test
# Test Statistics                  -0.219535
# p-value                           0.936153
# No. of lags used                  2.000000
# Number of observations used    1220.000000
# critical value (1%)              -3.435721
# critical value (5%)              -2.863912
# critical value (10%)             -2.568033
# dtype: float64

# %%
df_gold = pd.read_csv("GC=F.csv")
df_gold.head()
print(df_gold.describe())
print(df_gold.isnull().sum())
df_gold['Date'] = pd.to_datetime(df_gold['Date'])
df_gold.to_csv("GOLD_processed1.csv")
# Out:
#               Open         High  ...    Adj Close         Volume
# count  5191.000000  5191.000000  ...  5191.000000    5191.000000
# mean   1016.579002  1021.716298  ...  1016.435947    4268.031978
# std     489.309009   492.272125  ...   489.164715   24568.524415
# min     255.000000   256.100006  ...   255.100006       0.000000
# 25%     477.149994   478.399994  ...   477.699997      17.000000
# 50%    1172.699951  1177.800049  ...  1172.599976      94.000000
# 75%    1333.149964  1340.450012  ...  1333.400024     357.500000
# max    2045.500000  2063.000000  ...  2051.500000  386334.000000
#
# [8 rows x 6 columns]
# Date           0
# Open         112
# High         112
# Low          112
# Close        112
# Adj Close    112
# Volume       112
# dtype: int64

# %%
df_gold.shape
# Out:
# (5303, 7)

# %%
plotting_1(df_gold, "GOLD Closing Price")

# %%
df_closing_gold = df_gold["Close"]
test_stationarity(df_closing_gold)
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-146-20a02230ce58> in <module>()
#       1 df_closing_gold = df_gold["Close"]
# ----> 2 test_stationarity(df_closing_gold)
#
# <ipython-input-80-2c573978907d> in test_stationarity(timeseries)
#      14
#      15     print("Results of dickey fuller test")
# ---> 16     adft = adfuller(timeseries,autolag='AIC')
#      17
#      18     output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     255         if not regresults:
#     256             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 257                                        maxlag, autolag)
#     258         else:
#     259             icbest, bestlag, alres = _autolag(OLS, xdshort, fullRHS, startlag,
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#      90     method = method.lower()
#      91     for lag in range(startlag, startlag + maxlag + 1):
# ---> 92         mod_instance = mod(endog, exog[:, :lag], *modargs)
#      93         results[lag] = mod_instance.fit()
#      94
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
#     683         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 684                                   weights=weights, hasconst=hasconst, **kwargs)
#     685         nobs = self.exog.shape[0]
#     686         weights = self.weights
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     194     """
#     195     def __init__(self, endog, exog, **kwargs):
# --> 196         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     197         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     198
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     214
#     215     def __init__(self, endog, exog=None, **kwargs):
# --> 216         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     217         self.initialize()
#     218
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      66         hasconst = kwargs.pop('hasconst', None)
#      67         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 68                                       **kwargs)
#      69         self.k_constant = self.data.k_constant
#      70         self.exog = self.data.exog
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      89
#      90     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 91         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      92         # kwargs arrays could have changed, easier to just attach here
#      93         for key in kwargs:
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     633     klass = handle_data_class_factory(endog, exog)
#     634     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 635                  **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      78         self.const_idx = None
#      79         self.k_constant = 0
# ---> 80         self._handle_constant(hasconst)
#      81         self._check_integrity()
#      82         self._cache = {}
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#     124             ptp_ = np.ptp(self.exog, axis=0)
#     125             if not np.isfinite(ptp_).all():
# --> 126                 raise MissingDataError('exog contains inf or nans')
#     127             const_idx = np.where(ptp_ == 0)[0].squeeze()
#     128             self.k_constant = const_idx.size
#
# MissingDataError: exog contains inf or nans

# %%
df_samsung = pd.read_csv("005930.KS.csv")
df_samsung.head()
print(df_samsung.describe())
print(df_samsung.isnull().sum())
df_samsung['Date'] = pd.to_datetime(df_samsung['Date'])
df_samsung.to_csv("SAMSUNG_processed1.csv")
# Out:
#                Open          High  ...     Adj Close        Volume
# count   5394.000000   5394.000000  ...   5394.000000  5.394000e+03
# mean   22855.333704  23097.565814  ...  19976.255426  2.207162e+07
# std    17814.624512  17984.763802  ...  17412.698160  1.563503e+07
# min     2540.000000   2760.000000  ...   2117.926025  0.000000e+00
# 25%     9892.500000  10000.000000  ...   7728.877808  1.185518e+07
# 50%    15800.000000  15940.000000  ...  12825.604492  1.803800e+07
# 75%    29320.000000  29580.000000  ...  24583.120117  2.770875e+07
# max    90300.000000  96800.000000  ...  90597.414063  1.642150e+08
#
# [8 rows x 6 columns]
# Date         0
# Open         6
# High         6
# Low          6
# Close        6
# Adj Close    6
# Volume       6
# dtype: int64

# %%
plotting_1(df_samsung, "SAMSUNG Closing Price")

# %%
df_closing_samsung = df_samsung["Close"]
test_stationarity(df_closing_samsung)
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-148-94f48457da0a> in <module>()
#       1 df_closing_samsung = df_samsung["Close"]
# ----> 2 test_stationarity(df_closing_samsung)
#
# <ipython-input-80-2c573978907d> in test_stationarity(timeseries)
#      14
#      15     print("Results of dickey fuller test")
# ---> 16     adft = adfuller(timeseries,autolag='AIC')
#      17
#      18     output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     255         if not regresults:
#     256             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 257                                        maxlag, autolag)
#     258         else:
#     259             icbest, bestlag, alres = _autolag(OLS, xdshort, fullRHS, startlag,
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#      90     method = method.lower()
#      91     for lag in range(startlag, startlag + maxlag + 1):
# ---> 92         mod_instance = mod(endog, exog[:, :lag], *modargs)
#      93         results[lag] = mod_instance.fit()
#      94
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
#     683         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 684                                   weights=weights, hasconst=hasconst, **kwargs)
#     685         nobs = self.exog.shape[0]
#     686         weights = self.weights
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     194     """
#     195     def __init__(self, endog, exog, **kwargs):
# --> 196         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     197         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     198
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     214
#     215     def __init__(self, endog, exog=None, **kwargs):
# --> 216         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     217         self.initialize()
#     218
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      66         hasconst = kwargs.pop('hasconst', None)
#      67         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 68                                       **kwargs)
#      69         self.k_constant = self.data.k_constant
#      70         self.exog = self.data.exog
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      89
#      90     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 91         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      92         # kwargs arrays could have changed, easier to just attach here
#      93         for key in kwargs:
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     633     klass = handle_data_class_factory(endog, exog)
#     634     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 635                  **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      78         self.const_idx = None
#      79         self.k_constant = 0
# ---> 80         self._handle_constant(hasconst)
#      81         self._check_integrity()
#      82         self._cache = {}
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#     124             ptp_ = np.ptp(self.exog, axis=0)
#     125             if not np.isfinite(ptp_).all():
# --> 126                 raise MissingDataError('exog contains inf or nans')
#     127             const_idx = np.where(ptp_ == 0)[0].squeeze()
#     128             self.k_constant = const_idx.size
#
# MissingDataError: exog contains inf or nans

# %%
# subsetting data sets to match data available for all the companies in the study
def sub_data(data):
  year1 = []
  a = 0
  for a in range(len(data)):
    year1.append(data.Date[a].year)
    a = a + 1
  data["year"] = year1
  data_f = data[data["year"] > 2013]
  return data_f

# %%
df_google = sub_data(df_google)
df_disney = sub_data(df_disney)
df_gold = sub_data(df_gold)
df_microsoft = sub_data(df_microsoft)
df_apple = sub_data(df_apple)

# %%
df_samsung = sub_data(df_samsung)

# %%
plotting_1(df_apple, "APPLE (Processed Data) Closing Price")

# %%
df_closing_apple = df_apple["Close"]
test_stationarity(df_closing_apple)
# Out:
# Results of dickey fuller test
# Test Statistics                   1.256536
# p-value                           0.996354
# No. of lags used                 24.000000
# Number of observations used    1856.000000
# critical value (1%)              -3.433878
# critical value (5%)              -2.863099
# critical value (10%)             -2.567600
# dtype: float64

# %%
plotting_1(df_google, "GOOGLE (Processed Data) Closing Price")

# %%
df_closing_google = df_google["Close"]
test_stationarity(df_closing_google)
# Out:
# Results of dickey fuller test
# Test Statistics                   2.917847
# p-value                           1.000000
# No. of lags used                 26.000000
# Number of observations used    1857.000000
# critical value (1%)              -3.433876
# critical value (5%)              -2.863098
# critical value (10%)             -2.567599
# dtype: float64

# %%
result = seasonal_decompose(df_closing_apple, model='multiplicative', freq = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
df_oil = pd.read_csv("Macrotrends-crude-oil-prices-daily.csv")
df_oil.head()
# Out:
#        Date  Closing Value
# 0  1/2/1986          25.56
# 1  1/3/1986          26.00
# 2  1/6/1986          26.53
# 3  1/7/1986          25.85
# 4  1/8/1986          25.87

# %%
df_oil.shape
df_oil.columns = ['Date', 'Close']
print(df_oil.describe())
print(df_oil.isnull().sum())
df_oil['Date'] = pd.to_datetime(df_oil['Date'])
df_oil.to_csv("OIL_processed1.csv")
# Out:
#              Close
# count  8932.000000
# mean     44.241742
# std      28.740187
# min      10.250000
# 25%      19.840000
# 50%      32.465000
# 75%      62.972500
# max     145.310000
# Date     0
# Close    0
# dtype: int64

# %%
df_oil = sub_data(df_oil)

# %%
plotting_1(df_oil, "OIL (Processed Data) Closing Price")

# %%
df_closing_oil = df_oil["Close"]
test_stationarity(df_closing_oil)
# Out:
# Results of dickey fuller test
# Test Statistics                  -2.269789
# p-value                           0.181897
# No. of lags used                  9.000000
# Number of observations used    1858.000000
# critical value (1%)              -3.433874
# critical value (5%)              -2.863097
# critical value (10%)             -2.567599
# dtype: float64

# %%
df_apple.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'year'], dtype='object')

# %%
df_apple = df_apple.drop(['Open', 'High', 'Low','Adj Close', 'Volume'], axis = 1)

# %%
df_google = df_google.drop(['Open', 'High', 'Low','Adj Close', 'Volume', 'year'], axis = 1)
df_disney = df_disney.drop(['Open', 'High', 'Low','Adj Close', 'Volume', 'year'], axis = 1)
df_gold = df_gold.drop(['Open', 'High', 'Low','Adj Close', 'Volume', 'year'], axis = 1)
df_microsoft = df_microsoft.drop(['Open', 'High', 'Low','Adj Close', 'Volume', 'year'], axis = 1)
df_samsung = df_samsung.drop(['Open', 'High', 'Low','Adj Close', 'Volume', 'year'], axis = 1)

# %%
df_dell = df_dell.drop(['Open', 'High', 'Low','Adj Close', 'Volume'], axis = 1)

# %%
df_dell.columns = ["Date", "Close_dell"]

# %%
df_apple.columns = ["Date", "Close_apple", "Year"]

# %%
df_oil = df_oil.drop(['year'], axis = 1)

# %%
df_google.columns = ["Date", "Close_google"]
df_disney.columns = ["Date", "Close_disney"]
df_gold.columns = ["Date", "Close_gold"]
df_microsoft.columns = ["Date", "Close_microsoft"]
df_samsung.columns = ["Date", "Close_samsung"]
df_oil.columns = ["Date", "Close_Oil"]

# %%
df_f1 = pd.merge(df_apple, df_google, how ="outer", on = "Date")

# %%
df_f1.head()
# Out:
#         Date  Close_apple    Year  Close_google
# 0 2014-01-02    19.754642  2014.0    554.481689
# 1 2014-01-03    19.320715  2014.0    550.436829
# 2 2014-01-06    19.426071  2014.0    556.573853
# 3 2014-01-07    19.287144  2014.0    567.303589
# 4 2014-01-08    19.409286  2014.0    568.484192

# %%
df_f = pd.merge(df_f1, df_disney, how = "outer", on = "Date")

# %%
first_column = df_f.pop('Year')

df_f.insert(0, 'Year', first_column)

# %%
df_f = pd.merge(df_f, df_dell, how = "outer", on = "Date")

# %%
df_f = pd.merge(df_f, df_microsoft, how = "outer", on="Date")

# %%
df_f = pd.merge(df_f, df_samsung, how = "outer", on="Date")

# %%
df_f = pd.merge(df_f, df_oil, how = "outer", on="Date")

# %%
df_f = pd.merge(df_f, df_gold, how = "outer", on="Date")

# %%
df_f.head()
# Out:
#      Year       Date  Close_apple  ...  Close_samsung  Close_Oil   Close_gold
# 0  2014.0 2014-01-02    19.754642  ...        26180.0      95.14  1225.000000
# 1  2014.0 2014-01-03    19.320715  ...        25920.0      93.66  1238.400024
# 2  2014.0 2014-01-06    19.426071  ...        26140.0      93.12  1237.800049
# 3  2014.0 2014-01-07    19.287144  ...        26080.0      93.31  1229.400024
# 4  2014.0 2014-01-08    19.409286  ...        25820.0      91.90  1225.300049
#
# [5 rows x 10 columns]

# %%
df_f.isnull().sum()
# Out:
# Year                58
# Date                 0
# Close_apple         58
# Close_google        55
# Close_disney        55
# Close_dell         716
# Close_microsoft     55
# Close_samsung      105
# Close_Oil           71
# Close_gold          71
# dtype: int64

# %%
df_f.drop(columns = ["Close_dell"], inplace=True)

# %%
df_f.isnull().sum()
# Out:
# Year                58
# Date                 0
# Close_apple         58
# Close_google        55
# Close_disney        55
# Close_microsoft     55
# Close_samsung      105
# Close_Oil           71
# Close_gold          71
# dtype: int64

# %%
year1 = []
a = 0
for a in range(len(df_f)):
  year1.append(df_f.Date[a].year)
  a = a + 1
# Out:
# 1939

# %%
df_f["Year"] = year1

# %%
df_final = df_f.bfill().ffill()

# %%
df_final.isnull().sum()
# Out:
# Year               0
# Date               0
# Close_apple        0
# Close_google       0
# Close_disney       0
# Close_microsoft    0
# Close_samsung      0
# Close_Oil          0
# Close_gold         0
# dtype: int64

# %%
plt.rcParams['figure.figsize'] = (30, 20)

fig, axes = plt.subplots(nrows = 4, ncols = 2)

# Specify the features of interest
num_features = ['Close_apple', 'Close_google', 'Close_disney', 'Close_microsoft', 'Close_gold', 'Close_Oil', 'Close_samsung']
xaxes = num_features
yaxes = ['Value', 'Value', 'Value', 'Value', 'Value', 'Value', 'Value', 'Value']


# draw histograms
axes = axes.ravel()
for idx, ax in enumerate(axes):
    ax.hist(df_final[num_features[idx]].dropna(), bins=40)
    ax.set_xlabel(xaxes[idx], fontsize=20)
    ax.set_ylabel(yaxes[idx], fontsize=20)
    ax.tick_params(axis='both', labelsize=15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-130-9b8b5a8fc12e> in <module>()
#      13 axes = axes.ravel()
#      14 for idx, ax in enumerate(axes):
# ---> 15     ax.hist(df_final[num_features[idx]].dropna(), bins=40)
#      16     ax.set_xlabel(xaxes[idx], fontsize=20)
#      17     ax.set_ylabel(yaxes[idx], fontsize=20)
#
# IndexError: list index out of range

# %%
import seaborn as sns

# %%
sns.set(font_scale=1.6)
fig, ax = plt.subplots()
fig.set_size_inches(30, 30)
sns.heatmap(df_final.corr(),cmap='coolwarm',ax=ax,annot=True,linewidths=2, annot_kws={"size": 15})
plt.title('Correlation Heat Map', fontsize = 20)
plt.show()

# %%
df_final.Close_apple.describe()
# Out:
# count    1939.000000
# mean       52.332951
# std        34.255363
# min        17.849285
# 25%        28.092500
# 50%        39.884998
# 75%        57.421250
# max       143.160004
# Name: Close_apple, dtype: float64

# %%
df_final['rolling_mean'] = df_final['Close_apple'].rolling(12).mean()

# %%
df_final["rolling_mean"]=df_final.rolling_mean.bfill().ffill()

# %%
df_final["rolling_mean"].describe()
# Out:
# count    1939.000000
# mean       52.008065
# std        33.985031
# min        18.344047
# 25%        27.925209
# 50%        39.767292
# 75%        56.320937
# max       137.532501
# Name: rolling_mean, dtype: float64

# %%
param1 = 56.33

# %%
df_final['Buy'] = df_final['Close_apple'].apply(lambda c: 0 if c > param1 else 1)

# %%
df_final
# Out:
#       Year       Date  Close_apple  ...   Close_gold  Buy  rolling_mean
# 0     2014 2014-01-02    19.754642  ...  1225.000000    1     19.420833
# 1     2014 2014-01-03    19.320715  ...  1238.400024    1     19.420833
# 2     2014 2014-01-06    19.426071  ...  1237.800049    1     19.420833
# 3     2014 2014-01-07    19.287144  ...  1229.400024    1     19.420833
# 4     2014 2014-01-08    19.409286  ...  1225.300049    1     19.420833
# ...    ...        ...          ...  ...          ...  ...           ...
# 1934  2020 2020-11-26   133.979996  ...  1776.599976    0    133.979996
# 1935  2021 2021-01-18   133.979996  ...  1776.599976    0    133.979996
# 1936  2021 2021-02-15   133.979996  ...  1776.599976    0    133.979996
# 1937  2021 2021-04-02   133.979996  ...  1776.599976    0    133.979996
# 1938  2021 2021-05-31   133.979996  ...  1776.599976    0    133.979996
#
# [1939 rows x 11 columns]

# %%
plt.boxplot(df_final['Close_apple'])

plt.show()

# %%
#7:  Barchartse
#%matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# make subplots
fig, axes = plt.subplots(nrows = 1, ncols = 1)

# make the data read to feed into the visulizer
X_Canceled= df_final.replace({'Buy': {1: 'yes', 0: 'no'}}).groupby('Buy').size().reset_index(name='Counts')['Buy']
Y_Canceled = df_final.replace({'Buy': {1: 'yes', 0: 'no'}}).groupby('Buy').size().reset_index(name='Counts')['Counts']
# make the bar plot
axes.bar(X_Canceled, Y_Canceled)
axes.set_title('Buy', fontsize=25)
axes.set_ylabel('Not Buy', fontsize=20)
axes.tick_params(axis='both', labelsize=15)



plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
target = df_final["Buy"]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

# %%
df_model = df_final.drop(columns = ["Date", "rolling_mean", "Close_apple"])

# %%
df_model
# Out:
#       Year  Close_google  Close_disney  ...  Close_Oil   Close_gold  Buy
# 0     2014    554.481689     76.269997  ...      95.14  1225.000000    1
# 1     2014    550.436829     76.110001  ...      93.66  1238.400024    1
# 2     2014    556.573853     75.820000  ...      93.12  1237.800049    1
# 3     2014    567.303589     76.339996  ...      93.31  1229.400024    1
# 4     2014    568.484192     75.220001  ...      91.90  1225.300049    1
# ...    ...           ...           ...  ...        ...          ...  ...
# 1934  2020   2539.899902    178.350006  ...      52.64  1776.599976    0
# 1935  2021   2539.899902    178.350006  ...      52.64  1776.599976    0
# 1936  2021   2539.899902    178.350006  ...      52.64  1776.599976    0
# 1937  2021   2539.899902    178.350006  ...      52.64  1776.599976    0
# 1938  2021   2539.899902    178.350006  ...      52.64  1776.599976    0
#
# [1939 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_model.loc[:, df_model.columns != 'Buy'], target, test_size=0.5, random_state=22)

# %%
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ROCAUC

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_f = RandomForestClassifier()
model = random_f.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.013402061855670102
# Mean Squared Error: 0.013402061855670102
# Root Mean Squared Error: 0.11576727454540037

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print("Accuracy for Random Forest Cassifier:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy for Random Forest Cassifier: 0.98659793814433

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
#!pip install yellowbrick
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ROCAUC

from sklearn.neighbors import KNeighborsClassifier

# %%
nearest_n = KNeighborsClassifier(n_neighbors = 2).fit(X_train, y_train)


#The ConfusionMatrix visualizer taxes a model
classes = [1,0]
cm = ConfusionMatrix(nearest_n, classes=classes, labels = [0,1], percent=False)


cm.score(X_test, y_test)

for label in cm.ax.texts:
    label.set_size(20)

cm.poof()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy for Kneughbors:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy for Kneughbors: 0.98659793814433

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.013402061855670102
# Mean Squared Error: 0.013402061855670102
# Root Mean Squared Error: 0.11576727454540037

# %%
model = LogisticRegression()
classes = [1,0]
cm = ConfusionMatrix(model, classes=classes, percent=False, labels = [1, 0])

cm.fit(X_train, y_train)

cm.score(X_test, y_test)

for label in cm.ax.texts:
    label.set_size(30)

cm.poof()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy for Logistic regression:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy for Logistic regression: 0.98659793814433

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.013402061855670102
# Mean Squared Error: 0.013402061855670102
# Root Mean Squared Error: 0.11576727454540037

# %%
from sklearn.linear_model import LinearRegression

# %%
df_model_L = df_final.drop(columns = ["Date", "rolling_mean", "Buy"])

# %%
target = df_model_L["Close_apple"]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_model_L.loc[:, df_model_L.columns != 'Close_apple'], target, test_size=0.5, random_state=22)

# %%
y_pred = model.predict(X_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 51.61295202680413
# Mean Squared Error: 3868.817979241272
# Root Mean Squared Error: 62.199822984002715
